# %% [markdown]
# # Release date for GPUs in gpu_csv

# %%
import pandas as pd

# %%
gpu_release_dates = pd.read_csv('../data/gpu_release_dates.csv')

# %%
# can use this df for merge on the actual gpu dataframe, and compare sell date to release date
gpu_release_dates
# Out:
#                   GPU Release Date
# 0     Geforce GTX 960   2015-01-22
# 1     Geforce GTX 970   2014-09-19
# 2     Geforce GTX 980   2014-09-19
# 3    Geforce GTX 1060   2016-07-19
# 4    Geforce GTX 1070   2016-06-10
# 5    Geforce GTX 1080   2016-05-27
# 6   Geforce GTX titan   2013-02-19
# 7    Geforce RTX 2060   2019-01-07
# 8    Geforce RTX 2070   2018-10-17
# 9    Geforce RTX 2080   2018-09-20
# 10  Geforce RTX titan   2018-12-18
# 11   Geforce RTX 3060   2021-02-25
# 12   Geforce RTX 3070   2020-10-29
# 13   Geforce RTX 3080   2020-09-17
# 14   Geforce RTX 3080   2020-09-24
# 15   Geforce RTX 4060   2023-06-29
# 16   Geforce RTX 4070   2023-04-13
# 17   Geforce RTX 4080   2022-11-16
# 18   Geforce RTX 4080   2022-10-12
# 19      Radeon R9 290   2013-11-05
# 20     Radeon R9 290X   2013-10-24
# 21      Radeon RX 470   2016-08-04
# 22      Radeon RX 480   2016-06-29
# 23      Radeon RX 570   2017-04-18
# 24      Radeon RX 580   2017-04-18
# 25  Radeon RX 6700 XT   2021-03-18
# ...
