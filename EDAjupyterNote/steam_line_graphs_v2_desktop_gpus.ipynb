# %% [markdown]
# # Steam Data Over Time

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Load and clean STEAM data
steam_survey = pd.read_csv('https://raw.githubusercontent.com/jdegene/steamHWsurvey/master/shs.csv')
steam_dates = steam_survey[pd.to_datetime(steam_survey['date']).dt.year >= 2015].reset_index().drop(labels='index',axis=1)
steam_gpu = steam_dates[steam_dates['category'] == 'Video Card Description']
steam_gpu = steam_gpu.dropna()
steam_gpu['date'] = pd.to_datetime(steam_gpu['date'])

steam_gpu.head()
steam_gpu.reset_index()
# Out:
#       index       date                category  \
# 0       292 2015-01-01  Video Card Description
# 1       293 2015-01-01  Video Card Description
# 2       294 2015-01-01  Video Card Description
# 3       295 2015-01-01  Video Card Description
# 4       296 2015-01-01  Video Card Description
# ...     ...        ...                     ...
# 9538  34708 2023-10-01  Video Card Description
# 9539  34709 2023-10-01  Video Card Description
# 9540  34710 2023-10-01  Video Card Description
# 9541  34711 2023-10-01  Video Card Description
# 9542  34712 2023-10-01  Video Card Description
#
#                                     name  change  percentage
# 0                     AMD Radeon HD 4350  0.0025      0.0025
# 1                     AMD Radeon HD 4650  0.0029      0.0029
# 2                     AMD Radeon HD 4670  0.0024      0.0024
# 3                     AMD Radeon HD 4850  0.0026      0.0026
# 4                     AMD Radeon HD 4870  0.0016      0.0016
# ...                                  ...     ...         ...
# 9538  NVIDIA GeForce RTX 4070 Laptop GPU -0.0003      0.0016
# 9539          NVIDIA GeForce RTX 4070 Ti  0.0005      0.0090
# 9540             NVIDIA GeForce RTX 4080  0.0011      0.0062
# 9541             NVIDIA GeForce RTX 4090 -0.0010      0.0061
# 9542                               Other -0.0067      0.0956
#
# [9543 rows x 6 columns]

# %%
# Remove Strange entires
steam_gpu = steam_gpu[~steam_gpu['date'].isin(steam_gpu[(steam_gpu['name'] == 'Other') & (steam_gpu['percentage'] > 0.5)]['date'])]

# %%
steam_gpu = steam_gpu[(steam_gpu['name'].str.contains("AMD Radeon RX")) |
                      (steam_gpu['name'].str.contains("AMD Radeon Vega")) |
                      (steam_gpu['name'].str.contains("NVIDIA GeForce GTX")) |
                      (steam_gpu['name'].str.contains("NVIDIA GeForce RTX"))]

# %%
steam_gpu['name'].unique()
# Out:
# array(['AMD Radeon HD 4350', 'AMD Radeon HD 4650', 'AMD Radeon HD 4670',
#        'AMD Radeon HD 4850', 'AMD Radeon HD 4870', 'AMD Radeon HD 5450',
#        'AMD Radeon HD 5500 Series', 'AMD Radeon HD 5570',
#        'AMD Radeon HD 5670', 'AMD Radeon HD 5750', 'AMD Radeon HD 5770',
#        'AMD Radeon HD 5850', 'AMD Radeon HD 5870', 'AMD Radeon HD 6310',
#        'AMD Radeon HD 6320', 'AMD Radeon HD 6410D', 'AMD Radeon HD 6450',
#        'AMD Radeon HD 6480G', 'AMD Radeon HD 6490M',
#        'AMD Radeon HD 6520G', 'AMD Radeon HD 6530D', 'AMD Radeon HD 6570',
#        'AMD Radeon HD 6620G', 'AMD Radeon HD 6670', 'AMD Radeon HD 6750M',
#        'AMD Radeon HD 6770', 'AMD Radeon HD 6850', 'AMD Radeon HD 6870',
#        'AMD Radeon HD 6950', 'AMD Radeon HD 6970', 'AMD Radeon HD 7310',
#        'AMD Radeon HD 7480D', 'AMD Radeon HD 7520G + 7670M',
#        'AMD Radeon HD 7540D', 'AMD Radeon HD 7550M',
#        'AMD Radeon HD 7560D', 'AMD Radeon HD 7640G + 7670M',
#        'AMD Radeon HD 7660G + 7670M', 'AMD Radeon HD 7670M',
#        'AMD Radeon HD 7750', 'AMD Radeon HD 7770', 'AMD Radeon HD 7850',
#        'AMD Radeon HD 7870', 'AMD Radeon HD 7950', 'AMD Radeon HD 7970',
#        'AMD Radeon HD 8330', 'AMD Radeon HD 8400', 'AMD Radeon HD 8470D',
#        'AMD Radeon HD 8600', 'AMD Radeon HD 8650G',
#        'AMD Radeon HD 8800 Series', 'AMD Radeon R4 Graphics',
#        'AMD Radeon R7 200 Series', 'AMD Radeon R9 200 Series', 'ATI 760G',
#        'ATI Mobility Radeon HD 4200', 'ATI Mobility Radeon HD 4570',
#        'ATI Mobility Radeon HD 5470', 'ATI Mobility Radeon HD 5650',
#        'Intel G33/G31 Express', 'Intel G41 Express',
#        'Intel HD Graphics 2000', 'Intel HD Graphics 2500',
#        'Intel HD Graphics 3000', 'Intel HD Graphics 4000',
#        'Intel HD Graphics 4400', 'Intel HD Graphics 4600',
#        'Intel HD Graphics 5000', 'Intel Iris Graphics 5100',
#        'Intel Iris Pro Graphics 5200', 'Intel Ironlake (Mobile)',
#        'Intel ValleyView2 HD Graphics', 'Mobile Intel 4 Series Express',
#        'Mobile Intel 965 Express', 'NVIDIA GeForce 210',
#        'NVIDIA GeForce 310M', 'NVIDIA GeForce 6100',
#        'NVIDIA GeForce 610M', 'NVIDIA GeForce 8400',
#        'NVIDIA GeForce 840M', 'NVIDIA GeForce 8600',
#        'NVIDIA GeForce 8800', 'NVIDIA GeForce 9400',
#        'NVIDIA GeForce 9500', 'NVIDIA GeForce 9600',
#        'NVIDIA GeForce 9800', 'NVIDIA GeForce GT 220',
#        'NVIDIA GeForce GT 240', 'NVIDIA GeForce GT 330M',
#        'NVIDIA GeForce GT 430', 'NVIDIA GeForce GT 440',
#        'NVIDIA GeForce GT 520', 'NVIDIA GeForce GT 520M',
#        'NVIDIA GeForce GT 525M', 'NVIDIA GeForce GT 540M',
#        'NVIDIA GeForce GT 555M', 'NVIDIA GeForce GT 610',
#        'NVIDIA GeForce GT 620', 'NVIDIA GeForce GT 620M',
#        'NVIDIA GeForce GT 630', 'NVIDIA GeForce GT 630M',
#        'NVIDIA GeForce GT 635M', 'NVIDIA GeForce GT 640',
#        'NVIDIA GeForce GT 640M', 'NVIDIA GeForce GT 650M',
#        'NVIDIA GeForce GT 730', 'NVIDIA GeForce GT 740M',
#        'NVIDIA GeForce GT 750M', 'NVIDIA GeForce GT 755M',
#        'NVIDIA GeForce GTS 250', 'NVIDIA GeForce GTS 450',
#        'NVIDIA GeForce GTX 260', 'NVIDIA GeForce GTX 460',
#        'NVIDIA GeForce GTX 550 Ti', 'NVIDIA GeForce GTX 560',
#        'NVIDIA GeForce GTX 560 Ti', 'NVIDIA GeForce GTX 560M',
#        'NVIDIA GeForce GTX 570', 'NVIDIA GeForce GTX 580',
#        'NVIDIA GeForce GTX 650', 'NVIDIA GeForce GTX 650 Ti',
#        'NVIDIA GeForce GTX 650 Ti Boost', 'NVIDIA GeForce GTX 660',
#        'NVIDIA GeForce GTX 660 Ti', 'NVIDIA GeForce GTX 660M',
#        'NVIDIA GeForce GTX 670', 'NVIDIA GeForce GTX 680',
#        'NVIDIA GeForce GTX 750', 'NVIDIA GeForce GTX 750 Ti',
#        'NVIDIA GeForce GTX 760', 'NVIDIA GeForce GTX 765M',
#        'NVIDIA GeForce GTX 770', 'NVIDIA GeForce GTX 770M',
#        'NVIDIA GeForce GTX 780', 'NVIDIA GeForce GTX 780 Ti',
#        'NVIDIA GeForce GTX 850M', 'NVIDIA GeForce GTX 860M',
#        'NVIDIA GeForce GTX 870M', 'NVIDIA GeForce GTX 970',
#        'NVIDIA GeForce GTX 980', 'Other',
#        'AMD Radeon 6600M and 6700M Series', 'AMD Radeon HD 6700 Series',
#        'AMD Radeon HD 6800 Series', 'AMD Radeon HD 7400M Series',
#        'AMD Radeon HD 7520G', 'AMD Radeon HD 7640G',
#        'AMD Radeon HD 7660G', 'AMD Radeon HD 7700 Series',
#        'AMD Radeon HD 7800 Series', 'AMD Radeon HD 7900 Series',
#        'AMD Radeon HD 8500 Series', 'AMD Radeon HD 8570D',
#        'AMD Radeon HD 8600 Series', 'AMD Radeon R7 Graphics',
#        'ATI Mobility Radeon HD 5000 Series', 'ATI Radeon HD 5450',
#        'ATI Radeon HD 5500 Series', 'ATI Radeon HD 5700 Series',
#        'ATI Radeon HD 5800 Series', 'NVIDIA GeForce GT 740',
#        'NVIDIA GeForce GTX 745', 'NVIDIA GeForce GTX 960',
#        'NVIDIA GeForce GTX 970M', 'Desktop Haswell GT1',
#        'AMD Radeon HD 7600M Series', 'AMD Radeon HD 8370D',
#        'AMD Radeon HD 8610G', 'Intel HD Graphics 5500',
#        'Intel Iris Graphics 6100', 'NVIDIA GeForce GTX 950M',
#        'NVIDIA GeForce GTX 980M', 'AMD Radeon R7 M260',
#        'NVIDIA GeForce 940M', 'NVIDIA N16V-GM',
#        'AMD Radeon HD 8600M Series', 'AMD Radeon HD 8800M Series',
#        'Intel HD Graphics 6000', 'NVIDIA GeForce GTX 950',
#        'NVIDIA GeForce GTX 980 Ti', 'AMD Radeon R6 Graphics',
#        'NVIDIA GeForce GT 420', 'Intel HD Graphics - Braswell',
#        'Intel HD Graphics 520', 'NVIDIA GeForce 920A',
#        'NVIDIA GeForce GT 720', 'AMD Radeon HD 6900 Series',
#        'ATI Radeon HD 5570', 'ATI Radeon HD 5670',
#        'NVIDIA GeForce 9600 GT', 'AMD Radeon R5 Graphics',
#        'AMD Radeon R7 300 Series', 'AMD Radeon R7 M260 Series',
#        'AMD Radeon R9 380 Series', 'AMD Radeon R9 390 Series',
#        'Intel G41 Express Chipset', 'Intel HD Graphics 530',
#        'Intel Haswell', 'Intel Ironlake Arrandale', 'Intel Ivy Bridge',
#        'Intel Sandy Bridge', 'Intel Valleyview Baytrail',
#        'Mobile Intel 4 Series Express Chipset Family',
#        'NVIDIA GeForce 8400 GS', 'NVIDIA GeForce 8600 GT',
#        'NVIDIA GeForce 920M', 'NVIDIA GeForce 9400 GT',
#        'NVIDIA GeForce 9500 GT', 'NVIDIA GeForce 9800 GT',
#        'NVIDIA GeForce GT 720M', 'NVIDIA GeForce GTX 960M',
#        'AMD Radeon R5 M330', 'Intel Cherryview Cherrytrail',
#        'Intel G33/G31 Express Chipset Family', 'NVIDIA GeForce 930M',
#        'NVIDIA GeForce GTX 1070', 'NVIDIA GeForce GTX 1080',
#        'NVIDIA GeForce GTX 965M', 'NVIDIA GeForce GTX 1060',
#        'AMD Radeon RX 480', 'AMD Radeon RX 460', 'AMD Radeon RX 470',
#        'NVIDIA GeForce GTX 1050 Ti', 'Intel HD Graphics 620',
#        'Intel HD Graphics 630', 'NVIDIA GeForce 940MX',
#        'NVIDIA GeForce GT 710', 'NVIDIA GeForce GTX 1050',
#        'NVIDIA GeForce GTX 1080 Ti', 'NVIDIA GeForce GTX 1070 Ti',
#        'NVIDIA GeForce GT 1030', 'AMD Radeon RX 580', 'AMD Radeon RX 560',
#        'NVIDIA GeForce 920MX', 'NVIDIA GeForce MX150',
#        'AMD Radeon RX 550', 'Intel Iris Plus Graphics 640',
#        'Intel UHD Graphics 620', 'Intel HD Graphics',
#        'Intel UHD Graphics 630', 'NVIDIA GeForce RTX 2070',
#        'NVIDIA GeForce RTX 2080', 'AMD Radeon RX 570',
#        'AMD Radeon RX Vega', 'Intel HD Graphics 610',
#        'NVIDIA GeForce RTX 2080 Ti', 'NVIDIA GeForce RTX 2060',
#        'AMD Radeon Vega 8 Graphics', 'NVIDIA GeForce GTX 1660 Ti',
#        'NVIDIA GeForce GTX 1660', 'NVIDIA GeForce GTX 1650',
#        'NVIDIA GeForce MX130', 'Radeon RX 590 Series',
#        'AMD Radeon RX 580 2048SP', 'AMD Radeon RX 590 Series',
#        'AMD Radeon RX Vega 11 Graphics', 'NVIDIA GeForce RTX 2070 SUPER',
#        'AMD Radeon RX 5700 XT', 'NVIDIA GeForce RTX 2060 SUPER',
#        'NVIDIA GeForce RTX 2080 SUPER', 'NVIDIA GeForce MX110',
#        'AMD Radeon Pro 460', 'AMD Radeon RX 5700',
#        'NVIDIA GeForce GTX 1660 SUPER', 'NVIDIA GeForce MX250',
#        'AMD Radeon Vega 3 Graphics', 'AMD Radeon Vega 8 Mobile Graphics',
#        'Intel Iris Plus Graphics 655', 'Intel UHD Graphics 617',
#        'NVIDIA GeForce GTX 1650 SUPER', 'NVIDIA Graphics Device',
#        'Intel UHD Graphics', 'NVIDIA GeForce GTX 1650 Ti',
#        'AMD Radeon RX 5600 XT', 'Intel Iris Plus Graphics',
#        'AMD Radeon RX 5500 XT', 'AMD Radeon(TM) Graphics',
#        'NVIDIA GeForce RTX 2070 with Max-Q Design',
#        'NVIDIA GeForce RTX 3080', 'Intel(R) Iris(R) Plus Graphics',
#        'NVIDIA GeForce RTX 3060 Ti', 'NVIDIA GeForce RTX 3090',
#        'NVIDIA GeForce MX350', 'Intel(R) UHD Graphics',
#        'NVIDIA GeForce RTX 3070', 'NVIDIA GeForce RTX 3060',
#        'NVIDIA GeForce RTX 3060 Laptop GPU',
#        'Intel(R) Iris(R) Xe Graphics', 'Intel(R) UHD Graphics 630',
#        'NVIDIA GeForce MX230', 'NVIDIA GeForce RTX 3070 Laptop GPU',
#        'NVIDIA GeForce RTX 3050 Laptop GPU', 'NVIDIA GeForce RTX 3070 Ti',
#        'NVIDIA GeForce RTX 3080 Ti', 'AMD Radeon Graphics',
#        'AMD Radeon RX 6700 XT', 'NVIDIA GeForce MX330',
#        'NVIDIA GeForce MX450', 'NVIDIA GeForce RTX 3050',
#        'NVIDIA GeForce RTX 3050 Ti',
#        'NVIDIA GeForce RTX 3050 Ti Laptop GPU', 'Apple G13G',
#        'NVIDIA GeForce RTX 2060 with Max-Q Design', 'AMD Radeon RX 5500M',
#        'NVIDIA GeForce RTX 3080 Laptop GPU', 'AMD Radeon RX 6600 XT',
#        'AMD Radeon RX 6900 XT', 'AMD Radeon RX 6600',
#        'AMD Radeon RX 6800 XT', 'AMD AMD Custom GPU 0405',
#        'NVIDIA GeForce RTX 3070 Ti Laptop GPU', 'AMD Radeon RX 6500 XT',
#        'Intel(R) UHD Graphics 600', 'NVIDIA GeForce RTX 4090',
#        'NVIDIA GeForce RTX 4070 Ti', 'NVIDIA GeForce RTX 4080',
#        'AMD Radeon RX 6650 XT', 'NVIDIA GeForce RTX 4060 Laptop GPU',
#        'NVIDIA GeForce RTX 4070', 'AMD Radeon RX 6750 XT', 'AMD VANGOGH',
#        'NVIDIA GeForce RTX 4050 Laptop GPU', 'AMD Radeon RX 7900 XTX',
#        'NVIDIA GeForce RTX 4060 Ti', 'NVIDIA GeForce RTX T10-8',
#        'NVIDIA GeForce RTX 4060', 'NVIDIA GeForce RTX 4070 Laptop GPU',
#        'Intel Iris Xe Graphics', 'Intel UHD Graphics 600'], dtype=object)

# %%
def get_release_year(gpu_name: str):
    if gpu_name.startswith('AMD Radeon R4'):
        return 2014
    elif gpu_name.startswith('AMD Radeon R5'):
        return 2014

# %%
# %matplotlib inline
df_pivot = steam_gpu.pivot(index='date', columns='name', values='percentage')
# Fill NaN values with 0 if necessary
df_pivot = df_pivot.fillna(0)

# Create a stacked area plot
ax = df_pivot.plot.area(stacked=True, figsize=(10, 6))

# Customize the plot
ax.set_title('GPU Market Share Over Time')
ax.set_xlabel('Date')
ax.set_ylabel('Market Share (%)')
ax.legend(title='GPU Name', bbox_to_anchor=(1, 1), loc='upper left')
ax.grid(True)

# Show the plot
plt.show()
